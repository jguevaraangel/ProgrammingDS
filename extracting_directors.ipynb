# %%
import pandas as pd
import ast
# Extract director names

movies_df = pd.read_excel("movies.xlsx")

# Convert stringified lists to actual Python lists
movies_df['directors'] = movies_df['directors'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) and x.startswith('[') else []
)

# Now extract names and URLs as before
movies_df['director_names'] = movies_df['directors'].apply(
    lambda x: ', '.join([d.get('name', '') for d in x]) if isinstance(x, list) else ''
)

movies_df['director_urls'] = movies_df['directors'].apply(
    lambda x: ', '.join([d.get('url', '') for d in x]) if isinstance(x, list) else ''
)

# %%
movies_df
# Out:
#                                                  title  \
# 0                               1. The Penguin Lessons
# 1                            2. La fiebre de los ricos
# 2                              3. El juego del asesino
# 3                          4. La habitación de al lado
# 4                                        5. Hechizados
# ..                                                 ...
# 468  469. Juan Espino: El mejor luchador de todos l...
# 469                470. Athletes to Watch - Paris 2024
# 470                                  471. Película Nº1
# 471                         472. El eco de otras voces
# 472                                  473. The Streamer
#
#                                         url imdbRating   imdbVotes  metascore  \
# 0    https://www.imdb.com/title/tt26677014/        7,3       (655)       58.0
# 1    https://www.imdb.com/title/tt17677434/        5,5   (5,4 mil)        NaN
# 2     https://www.imdb.com/title/tt0327785/        5,8    (17 mil)       36.0
# 3    https://www.imdb.com/title/tt29439114/        6,8    (19 mil)       70.0
# 4     https://www.imdb.com/title/tt7215232/        5,6   (7,1 mil)       54.0
# ..                                      ...        ...         ...        ...
# 468  https://www.imdb.com/title/tt32991422/        NaN         NaN        NaN
# 469  https://www.imdb.com/title/tt32992679/        NaN         NaN        NaN
# 470  https://www.imdb.com/title/tt31124592/        NaN         NaN        NaN
# 471  https://www.imdb.com/title/tt36386095/        NaN         NaN        NaN
# 472  https://www.imdb.com/title/tt36413808/        NaN         NaN        NaN
#
#                                              directors  \
# 0                                                   []
# 1                                                   []
# 2    [{'name': 'J.J. Perry', 'url': 'https://www.im...
# 3                                                   []
# 4    [{'name': 'Vicky Jenson', 'url': 'https://www....
# ..                                                 ...
# 468                                                 []
# 469                                                 []
# 470                                                 []
# 471  [{'name': 'Adriana Domínguez', 'url': 'https:/...
# 472  [{'name': 'Lucas Figueroa', 'url': 'https://ww...
#
#                                              thespians     director_names  \
# 0                                                   []
# 1                                                   []
# 2    [{'name': 'Dave Bautista', 'url': 'https://www...         J.J. Perry
# 3                                                   []
# 4    [{'name': 'Rachel Zegler', 'url': 'https://www...       Vicky Jenson
# ..                                                 ...                ...
# 468                                                 []
# 469                                                 []
# 470                                                 []
# 471  [{'name': 'Adolfo Domínguez', 'url': 'https://...  Adriana Domínguez
# 472                                                 []     Lucas Figueroa
#
#                             director_urls
# 0
# 1
# 2    https://www.imdb.com/name/nm0675102/
# 3
# 4    https://www.imdb.com/name/nm0421776/
# ..                                    ...
# 468
# 469
# 470
# 471  https://www.imdb.com/name/nm1063497/
# 472  https://www.imdb.com/name/nm1883042/
#
# [473 rows x 9 columns]

# %%
# Get all non-empty director_urls, split by comma, and flatten
director_urls = movies_df[movies_df['director_urls'] != '']['director_urls'] \
    .str.split(', ') \
    .explode() \
    .tolist()

director_urls
# Out:
# ['https://www.imdb.com/name/nm0675102/',
#  'https://www.imdb.com/name/nm0421776/',
#  'https://www.imdb.com/name/nm0181579/',
#  'https://www.imdb.com/name/nm2008067/',
#  'https://www.imdb.com/name/nm10978790/',
#  'https://www.imdb.com/name/nm1400534/',
#  'https://www.imdb.com/name/nm16515310/',
#  'https://www.imdb.com/name/nm1891278/',
#  'https://www.imdb.com/name/nm1794876/',
#  'https://www.imdb.com/name/nm3705179/',
#  'https://www.imdb.com/name/nm0406529/',
#  'https://www.imdb.com/name/nm3390426/',
#  'https://www.imdb.com/name/nm14154881/',
#  'https://www.imdb.com/name/nm2163910/',
#  'https://www.imdb.com/name/nm12340639/',
#  'https://www.imdb.com/name/nm8124959/',
#  'https://www.imdb.com/name/nm7618908/',
#  'https://www.imdb.com/name/nm6758812/',
#  'https://www.imdb.com/name/nm0547621/',
#  'https://www.imdb.com/name/nm1847615/',
#  'https://www.imdb.com/name/nm14200738/',
#  'https://www.imdb.com/name/nm14976820/',
#  'https://www.imdb.com/name/nm14976821/',
#  'https://www.imdb.com/name/nm15895904/',
#  'https://www.imdb.com/name/nm9710905/',
#  'https://www.imdb.com/name/nm4900586/',
#  'https://www.imdb.com/name/nm5579280/',
#  'https://www.imdb.com/name/nm4335779/',
#  'https://www.imdb.com/name/nm13579538/',
#  'https://www.imdb.com/name/nm9677985/',
#  'https://www.imdb.com/name/nm3860375/',
#  'https://www.imdb.com/name/nm3732825/',
#  'https://www.imdb.com/name/nm8171751/',
#  'https://www.imdb.com/name/nm16657099/',
#  'https://www.imdb.com/name/nm17004598/',
#  'https://www.imdb.com/name/nm15031582/',
#  'https://www.imdb.com/name/nm16594424/',
#  'https://www.imdb.com/name/nm5198812/',
#  'https://www.imdb.com/name/nm13253001/',
#  'https://www.imdb.com/name/nm2014715/',
#  'https://www.imdb.com/name/nm6250367/',
#  'https://www.imdb.com/name/nm5253573/',
#  'https://www.imdb.com/name/nm16419180/',
#  'https://www.imdb.com/name/nm14790297/',
#  'https://www.imdb.com/name/nm9357959/',
#  'https://www.imdb.com/name/nm11346857/',
#  'https://www.imdb.com/name/nm16512592/',
#  'https://www.imdb.com/name/nm16573521/',
#  'https://www.imdb.com/name/nm7395759/',
#  'https://www.imdb.com/name/nm1431315/',
#  'https://www.imdb.com/name/nm1301484/',
#  'https://www.imdb.com/name/nm13120961/',
#  'https://www.imdb.com/name/nm15725665/',
#  'https://www.imdb.com/name/nm15979472/',
#  'https://www.imdb.com/name/nm1513634/',
#  'https://www.imdb.com/name/nm9936138/',
#  'https://www.imdb.com/name/nm14790297/',
#  'https://www.imdb.com/name/nm11771334/',
#  'https://www.imdb.com/name/nm17025928/',
#  'https://www.imdb.com/name/nm8016731/',
#  'https://www.imdb.com/name/nm11369760/',
#  'https://www.imdb.com/name/nm10460148/',
#  'https://www.imdb.com/name/nm15844820/',
#  'https://www.imdb.com/name/nm1872532/',
#  'https://www.imdb.com/name/nm1895649/',
#  'https://www.imdb.com/name/nm4670958/',
#  'https://www.imdb.com/name/nm15894189/',
#  'https://www.imdb.com/name/nm1031779/',
#  'https://www.imdb.com/name/nm9138558/',
#  'https://www.imdb.com/name/nm16541888/',
#  'https://www.imdb.com/name/nm1876864/',
#  'https://www.imdb.com/name/nm9039666/',
#  'https://www.imdb.com/name/nm10540239/',
#  'https://www.imdb.com/name/nm16531264/',
#  'https://www.imdb.com/name/nm13597757/',
#  'https://www.imdb.com/name/nm1063497/',
#  'https://www.imdb.com/name/nm1883042/']

# %%
len(director_urls)
# Out:
# 288

# %%
import requests
from bs4 import BeautifulSoup

# url = 'https://www.imdb.com/es/name/nm0634240/'

# %%
import requests
import re
import unidecode
from bs4 import BeautifulSoup
from bs4.element import Tag
import json

def get_director_raw_info(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
    }

    response = requests.get(url, headers=headers)
    response.raise_for_status()

    soup = BeautifulSoup(response.text, 'html.parser')
    dir_info_raw = soup.find_all('li', {'data-testid': True})
    
    # Extraer nombre del director desde el título
    title_tag = soup.find('title')
    name = title_tag.get_text(strip=True).split('-')[0].strip() if title_tag else 'Nombre no encontrado'

    return dir_info_raw, name

def get_director_structured_info(name, item: Tag):
    try:
        category = item.get("data-testid", default="no_category")

        if not category.startswith("cred"):
            return {"error": "unexpected category"}

        match = re.search(r'_(.*?)_', category)
        category_cleaned = unidecode.unidecode(match.group(1))

        info = item.find('a', {'aria-label': True})
        movie_name = info["aria-label"]
        url = f"https://www.imdb.com{info.get('href')}"

        rating_span = item.find('span', class_='ipc-rating-star--rating')
        rating = rating_span.get_text(strip=True) if rating_span else 'N/A'

        response = {
            "name": name,
            "category": category_cleaned,
            "movie_name": movie_name,
            "rating": rating,
            "url": url,
        }
        return response
    except Exception as ex:
        return {"error": f"{ex}"}

# %%
urls = director_urls

# %%
all_structured_data = []

for url in urls:
    try:
        raw_info, director_name = get_director_raw_info(url)
        
        structured_data = list(
            filter(
                lambda item: "error" not in item, 
                map(lambda item: get_director_structured_info(director_name, item), raw_info)
            )
        )
        
        all_structured_data.extend(structured_data)
    except Exception as e:
        print(f"Error procesando URL {url}: {e}")

# %%
import pandas as pd

df = pd.DataFrame(all_structured_data)

# %%
df
# Out:
#                 name  category                             movie_name rating  \
# 0         J.J. Perry    stunts            Avatar: El sentido del agua    7.5
# 1         J.J. Perry    stunts                              Samaritan    5.7
# 2         J.J. Perry    stunts                       Fast & Furious 9    5.2
# 3         J.J. Perry    stunts                         Sombra y hueso    7.5
# 4         J.J. Perry    stunts        Falcon y el Soldado de Invierno    7.1
# ...              ...       ...                                    ...    ...
# 5250  Lucas Figueroa  producer                                  Viral    4.4
# 5251  Lucas Figueroa  producer                                   Clip    N/A
# 5252  Lucas Figueroa  producer                      Boletos por favor    6.2
# 5253  Lucas Figueroa  producer  Porque hay cosas que nunca se olvidan    6.2
# 5254  Lucas Figueroa  producer                             Con que 24    5.3
#
#                                                     url
# 0     https://www.imdb.com/title/tt1630029/?ref_=nm_...
# 1     https://www.imdb.com/title/tt5500218/?ref_=nm_...
# 2     https://www.imdb.com/title/tt5433138/?ref_=nm_...
# 3     https://www.imdb.com/title/tt2403776/?ref_=nm_...
# 4     https://www.imdb.com/title/tt9208876/?ref_=nm_...
# ...                                                 ...
# 5250  https://www.imdb.com/title/tt2594078/?ref_=nm_...
# 5251  https://www.imdb.com/title/tt36413583/?ref_=nm...
# 5252  https://www.imdb.com/title/tt1298740/?ref_=nm_...
# 5253  https://www.imdb.com/title/tt1292572/?ref_=nm_...
# 5254  https://www.imdb.com/title/tt0441156/?ref_=nm_...
#
# [5255 rows x 5 columns]

# %%
df.to_csv("directors_info.csv", index=False)
